# %%
# %matplotlib inline
import os
import sys
import cv2
import utils
import imageio
import numpy as np
from nuscenes.utils.data_classes import LidarPointCloud
from nuscenes.nuscenes import NuScenes
from scipy.spatial.transform import Rotation as R
import matplotlib.pyplot as plt
from pyquaternion import Quaternion
from collections import Counter
import sys
sys.path.append('./')

# %%
# Paths
NUSCENES_LIDAR_DIR = "G:\\intern\\pointcloud\\dataset\\v1.0-mini\\samples\\LIDAR_TOP"
NUSCENES_OUTPUT_DIR = "G:\\intern\\pointcloud\\dataset\\v1.0-mini\\bev\\nuscenes\\samples"
NUSCENES_OUTPUT_DIR_LABEL = "G:\\intern\\pointcloud\\dataset\\v1.0-mini\\bev\\nuscenes\\annotations"
# lidar boundarys for Bird's Eye View
BOUNDARY = {
    "minX": -25,
    "maxX": 25,
    "minY": -25,
    "maxY": 25,
    "minZ": -2.73,
    "maxZ": 1.27
}
BB_BOUNDARY = {
    "minX": -25,
    "maxX": 25,
    "minY": -25,
    "maxY": 25,
}
img_height = 479
img_width = 479
discretization = (BOUNDARY["maxX"] - BOUNDARY["minX"]) / img_height
dataset = "nuscenes"
lidar_path = NUSCENES_LIDAR_DIR
output_dir = NUSCENES_OUTPUT_DIR
output_dir_label = NUSCENES_OUTPUT_DIR_LABEL

# %%
def removePoints(PointCloud, BoundaryCond):
    # Boundary condition
    minX = BoundaryCond['minX']
    maxX = BoundaryCond['maxX']
    minY = BoundaryCond['minY']
    maxY = BoundaryCond['maxY']
    minZ = BoundaryCond['minZ']
    maxZ = BoundaryCond['maxZ']

    # Remove the point out of range x,y,z
    mask = np.where(
            (PointCloud[:, 0] >= minX) &
            (PointCloud[:, 0] <= maxX) &
            (PointCloud[:, 1] >= minY) &
            (PointCloud[:, 1] <= maxY) &
            (PointCloud[:, 2] >= minZ) &
            (PointCloud[:, 2] <= maxZ)
            )
    PointCloud = PointCloud[mask]
    PointCloud[:, 2] = PointCloud[:, 2] - minZ
    return PointCloud

def removePoints_bb(PointCloud, BoundaryCond):
    # Boundary condition
    minX = BoundaryCond['minX']
    maxX = BoundaryCond['maxX']
    minY = BoundaryCond['minY']
    maxY = BoundaryCond['maxY']

    # Remove the point out of range x,y,z
    mask = np.where(
            (PointCloud[:, 0] >= minX) &
            (PointCloud[:, 0] <= maxX) &
            (PointCloud[:, 1] >= minY) &
            (PointCloud[:, 1] <= maxY) 
            )
    PointCloud = PointCloud[mask]
    return PointCloud

# %%
def makeBVFeature(PointCloud_, BoundaryCond, img_height, img_width, Discretization):
    Height = img_height + 1
    Width = img_width + 1

    # Discretize Feature Map
    PointCloud = np.copy(PointCloud_)
    PointCloud[:, 0] = np.int_(np.floor(PointCloud[:, 0] / Discretization) + Height / 2)
    PointCloud[:, 1] = np.int_(np.floor(PointCloud[:, 1] / Discretization) + Width / 2)
    # sort-3times
    indices = np.lexsort((-PointCloud[:, 2], PointCloud[:, 1], PointCloud[:, 0]))
    PointCloud = PointCloud[indices]

    # Height Map
    heightMap = np.zeros((Height, Width))

    # because of the rounding of points, there are many identical points
    _, indices = np.unique(PointCloud[:, 0:2], axis=0, return_index=True)
    PointCloud_frac = PointCloud[indices]

    # Some important problem is image coordinate is (y,x), not (x,y)
    max_height = float(np.abs(BoundaryCond['maxZ'] - BoundaryCond['minZ']))
    heightMap[np.int_(PointCloud_frac[:, 0]), np.int_(PointCloud_frac[:, 1])] = PointCloud_frac[:, 2] / max_height
    heightMap_normalized = (heightMap - BoundaryCond['minZ'])/abs(BoundaryCond['maxZ']-BoundaryCond['minZ'])  # Normalize to [0, 1]

    return heightMap_normalized

# %%
def project_3dbox(box, BB_BOUNDARY, img_height, img_width, Discretization):
    Height = img_height + 1
    Width = img_width + 1
    corners = box.get_corners(view=np.eye(4))
    corners[:, 0] = -corners[:, 0]
    corners[:, 0] = np.int_(np.floor(corners[:, 0] / Discretization) + Height / 2)
    corners[:, 1] = np.int_(np.floor(corners[:, 1] / Discretization) + Width / 2)
    
    return corners

# %%
nusc = NuScenes(version='v1.0-mini', dataroot='../v1.0-mini', verbose=False)
sensor = 'LIDAR_TOP'
for i in range(0,len(nusc.sample)):
    points= nusc.obtain_points(nusc.sample[i]['data'][sensor],axes_limit = 30, underlay_map=False, use_flat_vehicle_coordinates= True)
    data_path, box_list, cam_intrinsic = nusc.get_sample_data(nusc.sample[i]['data'][sensor],use_flat_vehicle_coordinates=True)
    r = R.from_quat([0, 0, np.sin((np.pi / 4)*3), np.cos((np.pi / 4)*3)])
    points[:3, :] = np.dot(r.as_matrix(), points[:3, :])
    lidar_pc = points.T
    print("Processing file (%s|%s)" % (i+1, len(nusc.sample)))
    lidar_pc_filtered = removePoints(lidar_pc, BOUNDARY)
    discretization = (BOUNDARY["maxX"] - BOUNDARY["minX"]) / img_height
    lidar_bev_height = makeBVFeature(lidar_pc_filtered, BOUNDARY, img_height, img_width, discretization)
    lidar_bev_mask = lidar_bev_height > np.min(lidar_bev_height)
    lidar_grey = lidar_bev_mask.astype(int)
    output_filename = 'bv_' + str(i+1) + '.png'
    output_filepath = os.path.join(output_dir, output_filename)
    img_bv = (255*lidar_grey).astype(np.uint8)
    img_bv = np.rot90(img_bv,-1)
    img_bv_rgb = cv2.cvtColor(img_bv, cv2.COLOR_GRAY2RGB)
    cv2.imwrite(output_filepath,img_bv_rgb)
    img = np.zeros([480, 480, 3], np.uint8)
    img[:,:,1] = 255
#     img = cv2.imread(output_filepath)
    
    for box in box_list: 
        corners = project_3dbox(box, BB_BOUNDARY, img_height, img_width, discretization)
        if "human" in box.name:
            color = (0,0,255) #red
        elif "vehicle" in box.name:
            color = (0,255,255) #yellow
        elif "movable_object" in box.name:
            color = (255,0,0) #blue
        else:
            color = (255,0,255) # pink
        res = cv2.fillConvexPoly(img, np.int32([corners]), color)
        img = res
    
    img=np.rot90(img,-1)
#     cv2.imshow('fillpoly', res)
#     output_filename_label = 'merged_' + str(i+1) + '.png'
    output_filename_label = 'label_' + str(i+1) + '.png'
    output_filepath_label = os.path.join(output_dir_label, output_filename_label)
    cv2.imwrite(output_filepath_label,img)
print("\nSuccessfully transformed all '%s' lidar pointclouds" % dataset)
# Out:
# Processing file (1|404)
# Processing file (2|404)
# Processing file (3|404)
# Processing file (4|404)
# Processing file (5|404)
# Processing file (6|404)
# Processing file (7|404)
# Processing file (8|404)
# Processing file (9|404)
# Processing file (10|404)
# Processing file (11|404)
# Processing file (12|404)
# Processing file (13|404)
# Processing file (14|404)
# Processing file (15|404)
# Processing file (16|404)
# Processing file (17|404)
# Processing file (18|404)
# Processing file (19|404)
# Processing file (20|404)
# Processing file (21|404)
# Processing file (22|404)
# Processing file (23|404)
# Processing file (24|404)
# Processing file (25|404)
# Processing file (26|404)
# Processing file (27|404)
# Processing file (28|404)
# Processing file (29|404)
# Processing file (30|404)
# Processing file (31|404)
# Processing file (32|404)
# Processing file (33|404)
# Processing file (34|404)
# Processing file (35|404)
# Processing file (36|404)
# Processing file (37|404)
# Processing file (38|404)
# Processing file (39|404)
# Processing file (40|404)
# Processing file (41|404)
# Processing file (42|404)
# Processing file (43|404)
# Processing file (44|404)
# Processing file (45|404)
# Processing file (46|404)
# Processing file (47|404)
# Processing file (48|404)
# Processing file (49|404)
# Processing file (50|404)
# Processing file (51|404)
# Processing file (52|404)
# Processing file (53|404)
# Processing file (54|404)
# Processing file (55|404)
# Processing file (56|404)
# Processing file (57|404)
# Processing file (58|404)
# Processing file (59|404)
# Processing file (60|404)
# Processing file (61|404)
# Processing file (62|404)
# Processing file (63|404)
# Processing file (64|404)
# Processing file (65|404)
# Processing file (66|404)
# Processing file (67|404)
# Processing file (68|404)
# Processing file (69|404)
# Processing file (70|404)
# Processing file (71|404)
# Processing file (72|404)
# Processing file (73|404)
# Processing file (74|404)
# Processing file (75|404)
# Processing file (76|404)
# Processing file (77|404)
# Processing file (78|404)
# Processing file (79|404)
# Processing file (80|404)
# Processing file (81|404)
# Processing file (82|404)
# Processing file (83|404)
# Processing file (84|404)
# Processing file (85|404)
# Processing file (86|404)
# Processing file (87|404)
# Processing file (88|404)
# Processing file (89|404)
# Processing file (90|404)
# Processing file (91|404)
# Processing file (92|404)
# Processing file (93|404)
# Processing file (94|404)
# Processing file (95|404)
# Processing file (96|404)
# Processing file (97|404)
# Processing file (98|404)
# Processing file (99|404)
# Processing file (100|404)
# Processing file (101|404)
# Processing file (102|404)
# Processing file (103|404)
# Processing file (104|404)
# Processing file (105|404)
# Processing file (106|404)
# Processing file (107|404)
# Processing file (108|404)
# Processing file (109|404)
# Processing file (110|404)
# Processing file (111|404)
# Processing file (112|404)
# Processing file (113|404)
# Processing file (114|404)
# Processing file (115|404)
# Processing file (116|404)
# Processing file (117|404)
# Processing file (118|404)
# Processing file (119|404)
# Processing file (120|404)
# Processing file (121|404)
# Processing file (122|404)
# Processing file (123|404)
# Processing file (124|404)
# Processing file (125|404)
# Processing file (126|404)
# Processing file (127|404)
# Processing file (128|404)
# Processing file (129|404)
# Processing file (130|404)
# Processing file (131|404)
# Processing file (132|404)
# Processing file (133|404)
# Processing file (134|404)
# Processing file (135|404)
# Processing file (136|404)
# Processing file (137|404)
# Processing file (138|404)
# Processing file (139|404)
# Processing file (140|404)
# Processing file (141|404)
# Processing file (142|404)
# Processing file (143|404)
# Processing file (144|404)
# Processing file (145|404)
# Processing file (146|404)
# Processing file (147|404)
# Processing file (148|404)
# Processing file (149|404)
# Processing file (150|404)
# Processing file (151|404)
# Processing file (152|404)
# Processing file (153|404)
# Processing file (154|404)
# Processing file (155|404)
# Processing file (156|404)
# Processing file (157|404)
# Processing file (158|404)
# Processing file (159|404)
# Processing file (160|404)
# Processing file (161|404)
# Processing file (162|404)
# Processing file (163|404)
# Processing file (164|404)
# Processing file (165|404)
# Processing file (166|404)
# Processing file (167|404)
# Processing file (168|404)
# Processing file (169|404)
# Processing file (170|404)
# Processing file (171|404)
# Processing file (172|404)
# Processing file (173|404)
# Processing file (174|404)
# Processing file (175|404)
# Processing file (176|404)
# Processing file (177|404)
# Processing file (178|404)
# Processing file (179|404)
# Processing file (180|404)
# Processing file (181|404)
# Processing file (182|404)
# Processing file (183|404)
# Processing file (184|404)
# Processing file (185|404)
# Processing file (186|404)
# Processing file (187|404)
# Processing file (188|404)
# Processing file (189|404)
# Processing file (190|404)
# Processing file (191|404)
# Processing file (192|404)
# Processing file (193|404)
# Processing file (194|404)
# Processing file (195|404)
# Processing file (196|404)
# Processing file (197|404)
# Processing file (198|404)
# Processing file (199|404)
# Processing file (200|404)
# Processing file (201|404)
# Processing file (202|404)
# Processing file (203|404)
# Processing file (204|404)
# Processing file (205|404)
# Processing file (206|404)
# Processing file (207|404)
# Processing file (208|404)
# Processing file (209|404)
# Processing file (210|404)
# Processing file (211|404)
# Processing file (212|404)
# Processing file (213|404)
# Processing file (214|404)
# Processing file (215|404)
# Processing file (216|404)
# Processing file (217|404)
# Processing file (218|404)
# Processing file (219|404)
# Processing file (220|404)
# Processing file (221|404)
# Processing file (222|404)
# Processing file (223|404)
# Processing file (224|404)
# Processing file (225|404)
# Processing file (226|404)
# Processing file (227|404)
# Processing file (228|404)
# Processing file (229|404)
# Processing file (230|404)
# Processing file (231|404)
# Processing file (232|404)
# Processing file (233|404)
# Processing file (234|404)
# Processing file (235|404)
# Processing file (236|404)
# Processing file (237|404)
# Processing file (238|404)
# Processing file (239|404)
# Processing file (240|404)
# Processing file (241|404)
# Processing file (242|404)
# Processing file (243|404)
# Processing file (244|404)
# Processing file (245|404)
# Processing file (246|404)
# Processing file (247|404)
# Processing file (248|404)
# Processing file (249|404)
# Processing file (250|404)
# Processing file (251|404)
# Processing file (252|404)
# Processing file (253|404)
# Processing file (254|404)
# Processing file (255|404)
# Processing file (256|404)
# Processing file (257|404)
# Processing file (258|404)
# Processing file (259|404)
# Processing file (260|404)
# Processing file (261|404)
# Processing file (262|404)
# Processing file (263|404)
# Processing file (264|404)
# Processing file (265|404)
# Processing file (266|404)
# Processing file (267|404)
# Processing file (268|404)
# Processing file (269|404)
# Processing file (270|404)
# Processing file (271|404)
# Processing file (272|404)
# Processing file (273|404)
# Processing file (274|404)
# Processing file (275|404)
# Processing file (276|404)
# Processing file (277|404)
# Processing file (278|404)
# Processing file (279|404)
# Processing file (280|404)
# Processing file (281|404)
# Processing file (282|404)
# Processing file (283|404)
# Processing file (284|404)
# Processing file (285|404)
# Processing file (286|404)
# Processing file (287|404)
# Processing file (288|404)
# Processing file (289|404)
# Processing file (290|404)
# Processing file (291|404)
# Processing file (292|404)
# Processing file (293|404)
# Processing file (294|404)
# Processing file (295|404)
# Processing file (296|404)
# Processing file (297|404)
# Processing file (298|404)
# Processing file (299|404)
# Processing file (300|404)
# Processing file (301|404)
# Processing file (302|404)
# Processing file (303|404)
# Processing file (304|404)
# Processing file (305|404)
# Processing file (306|404)
# Processing file (307|404)
# Processing file (308|404)
# Processing file (309|404)
# Processing file (310|404)
# Processing file (311|404)
# Processing file (312|404)
# Processing file (313|404)
# Processing file (314|404)
# Processing file (315|404)
# Processing file (316|404)
# Processing file (317|404)
# Processing file (318|404)
# Processing file (319|404)
# Processing file (320|404)
# Processing file (321|404)
# Processing file (322|404)
# Processing file (323|404)
# Processing file (324|404)
# Processing file (325|404)
# Processing file (326|404)
# Processing file (327|404)
# Processing file (328|404)
# Processing file (329|404)
# Processing file (330|404)
# Processing file (331|404)
# Processing file (332|404)
# Processing file (333|404)
# Processing file (334|404)
# Processing file (335|404)
# Processing file (336|404)
# Processing file (337|404)
# Processing file (338|404)
# Processing file (339|404)
# Processing file (340|404)
# Processing file (341|404)
# Processing file (342|404)
# Processing file (343|404)
# Processing file (344|404)
# Processing file (345|404)
# Processing file (346|404)
# Processing file (347|404)
# Processing file (348|404)
# Processing file (349|404)
# Processing file (350|404)
# Processing file (351|404)
# Processing file (352|404)
# Processing file (353|404)
# Processing file (354|404)
# Processing file (355|404)
# Processing file (356|404)
# Processing file (357|404)
# Processing file (358|404)
# Processing file (359|404)
# Processing file (360|404)
# Processing file (361|404)
# Processing file (362|404)
# Processing file (363|404)
# Processing file (364|404)
# Processing file (365|404)
# Processing file (366|404)
# Processing file (367|404)
# Processing file (368|404)
# Processing file (369|404)
# Processing file (370|404)
# Processing file (371|404)
# Processing file (372|404)
# Processing file (373|404)
# Processing file (374|404)
# Processing file (375|404)
# Processing file (376|404)
# Processing file (377|404)
# Processing file (378|404)
# Processing file (379|404)
# Processing file (380|404)
# Processing file (381|404)
# Processing file (382|404)
# Processing file (383|404)
# Processing file (384|404)
# Processing file (385|404)
# Processing file (386|404)
# Processing file (387|404)
# Processing file (388|404)
# Processing file (389|404)
# Processing file (390|404)
# Processing file (391|404)
# Processing file (392|404)
# Processing file (393|404)
# Processing file (394|404)
# Processing file (395|404)
# Processing file (396|404)
# Processing file (397|404)
# Processing file (398|404)
# Processing file (399|404)
# Processing file (400|404)
# Processing file (401|404)
# Processing file (402|404)
# Processing file (403|404)
# Processing file (404|404)
#
# Successfully transformed all 'nuscenes' lidar pointclouds
